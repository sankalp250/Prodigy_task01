# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('worldpopulationdata.csv')

# %%
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code        2022
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0  \
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...  \
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %%
df['Country Name'].nunique()
# Out:
# 217

# %% [markdown]
# Dropping unnecessary columns

# %%
df.drop(['Series Name'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %% [markdown]
# Extraction of top 10 countries wrt population

# %%
total_population = df[df['Series Code'] == 'SP.POP.TOTL']

total_population_sorted = total_population.sort_values(by="2022", ascending=False)

top_ten_countries = total_population_sorted.head(10)
print("Top ten countries of total population\n")
print(top_ten_countries[['Country Name']] )
# Out:
# Top ten countries of total population
#
#            Country Name
# 89                India
# 41                China
# 206       United States
# 90            Indonesia
# 149            Pakistan
# 144             Nigeria
# 26               Brazil
# 15           Bangladesh
# 161  Russian Federation
# 127              Mexico

# %% [markdown]
# Difference between the year 2022 to 2012

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2,2,1)
sns.barplot(x="2022", y="Country Name", data=top_ten_countries,orient='h') # type: ignore
plt.title("Top Ten Countries of Total Population (2022)")
plt.xlabel("Total Population")
plt.ylabel("Country")
plt.show()

plt.figure(figsize=(12, 6))
plt.subplot(2,2,2)
sns.barplot(x="2012", y="Country Name", data=top_ten_countries,orient='h') # type: ignore
plt.title("Top Ten Countries with Total Population (2012)")
plt.xlabel("Total Population")
plt.ylabel("Country")
plt.show()

# %% [markdown]
# Total male population rise in top 10 most populated country

# %%
total_male_population = df[df['Series Code'] == 'SP.POP.TOTL.MA.IN']

total_male_pop = total_male_population.sort_values(by="2022",ascending= False)
male_top_countries = total_male_pop.head(10)

print(male_top_countries[['Country Name']])
# Out:
#            Country Name
# 523               India
# 475               China
# 640       United States
# 524           Indonesia
# 583            Pakistan
# 578             Nigeria
# 460              Brazil
# 449          Bangladesh
# 595  Russian Federation
# 561              Mexico

# %%
sns.barplot(x = "2022" , y ="Country Name" , data = male_top_countries,orient='h')
plt.title('Top 10 countries with most male population')
plt.xlabel('male population')
plt.ylabel('country')
plt.show()

sns.barplot(x = "2012" , y ="Country Name" , data = male_top_countries,orient='h')
plt.title('Top 10 countries with most male population')
plt.xlabel('male population')
plt.ylabel('country')
plt.show()

# %%
total_female_population = df[df['Series Code'] == 'SP.POP.TOTL.FE.IN']

total_female_pop = total_female_population.sort_values(by="2022",ascending= False)
female_top_countries = total_female_pop.head(10)

print(female_top_countries[['Country Name']])
# Out:
#            Country Name
# 258               China
# 306               India
# 423       United States
# 307           Indonesia
# 366            Pakistan
# 243              Brazil
# 361             Nigeria
# 232          Bangladesh
# 378  Russian Federation
# 344              Mexico

# %%
sns.barplot(x = "2022" , y ="Country Name" , data = female_top_countries,orient='h')
plt.title('Top 10 countries with most female population')
plt.xlabel('female population')
plt.ylabel('country')
plt.show()

sns.barplot(x = "2012" , y ="Country Name" , data = female_top_countries,orient='h')
plt.title('Top 10 countries with most female population')
plt.xlabel('female population')
plt.ylabel('country')
plt.show()
